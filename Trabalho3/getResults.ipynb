# %%
import pandas as pd

# %%
df = pd.read_csv("resultado.csv",names=["program","nx","num_threads","tempo"])

# %%
df
# Out:
#               program    nx  num_threads      tempo
# 0           ./laplace   512            1   4.204004
# 1           ./laplace  1024            1  17.548815
# 2           ./laplace  2048            1  76.868279
# 3       ./laplace_vec   512            1   3.248734
# 4       ./laplace_vec  1024            1  13.591241
# 5       ./laplace_vec  2048            1  60.024839
# 6       ./laplace_omp   512            1   3.986706
# 7       ./laplace_omp   512            2   2.481313
# 8       ./laplace_omp   512            3   2.664023
# 9       ./laplace_omp  1024            1  15.337704
# 10      ./laplace_omp  1024            2   9.218728
# 11      ./laplace_omp  1024            3   9.876598
# 12      ./laplace_omp  2048            1  65.666409
# 13      ./laplace_omp  2048            2  36.850189
# 14      ./laplace_omp  2048            3  38.591171
# 15  ./laplace_omp_vec   512            1   2.076559
# 16  ./laplace_omp_vec   512            2   1.225685
# ...
